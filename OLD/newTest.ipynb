# %% [markdown]
# # lab code
# # <(6O9)>

# %%
import matplotlib.pyplot as plt
import  numpy as np
from PIL import Image

# %%
import sys  

# In phiên bản Python  
print("Phiên bản Python hiện tại là:", sys.version)  

# Nếu chỉ cần các thông tin cụ thể hơn  
print("Thông tin chi tiết:", sys.version_info)
# Out:
# Phiên bản Python hiện tại là: 3.12.7 (main, Nov 22 2024, 20:28:41)  [GCC UCRT 14.2.0 64 bit (AMD64)]
# Thông tin chi tiết: sys.version_info(major=3, minor=12, micro=7, releaselevel='final', serial=0)

# %%
test_path = "test_g_img_001.jpg"
test_img = Image.open(test_path)
plt.imshow(test_img)

# %%
x = [ 1, 2, 3, 4, 5, 6, ]
y = [0, 2, 10, 4, 5, 5]
plt.plot(x, y)
plt.title("đồ thị dân số")
plt.axis("tight")
plt.show()

# %%
from matplotlib.lines import lineStyles


x = np.linspace(0,10, 1000)
plt.plot(x, np.sin(x), color="blue", linestyle="dashed", label = "sin(x)")
plt.plot(x, np.cos(x), color="yellow", linestyle="dashed", label = "cos(x)")

# plt.xlabel("bien X")
# plt.ylabel("F(x)")

# plt.legend();

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10,5))
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x))
ax3.scatter(np.random.random(10), np.random.random(10))

# %%
a = np.array([0,1,2,3,4,5,6,7])
b = np.random.random_integers(1, 100, 8)
b
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_26000\2265491331.py:2: DeprecationWarning: This function is deprecated. Please call randint(1, 100 + 1) instead
#   b = np.random.random_integers(1, 100, 8)
# array([21, 31, 34, 49, 14, 87,  9, 26], dtype=int32)

# %%
plt.
